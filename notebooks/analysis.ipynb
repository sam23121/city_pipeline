# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/20181029_d1_0800_0830.csv", sep = ';', on_bad_lines='skip')

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['track_id', ' type', ' traveled_d', ' avg_speed', ' lat', ' lon',
#        ' speed', ' lon_acc', ' lat_acc', ' time'],
#       dtype='object')>

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.shape
# Out:
# (78, 10)
